# %%
class Person():
  folder = []                 # 클래스 속성 -> 클래스에 속한다(공공제) 모든 인스턴스에서 접근이 가능하다

  def add_files(self, file):  
    self.folder.append(file)  # 클래스 이름으로 클래스 속성에 접근할 수 있다    

jin = Person()
jin.add_files('txt')

paul = Person()
paul.add_files('img')

print(jin.folder)
print(paul.folder)
# Out:
# 1

# %%
class Person:
    def __init__(self):
        self.__weight = 78

    def print_weight(self):
        print(self.__weight)

jin = Person()
jin.__weight = 67
print(jin.__weight)
# Out:
# 67

# %%
# 모듈
# -> 변수, 함수, 클래스 등을 모아서 파일로 저장해둔 것

# 패키지
# - 여러개의 모듈을 폴더로 묶어 체계적으로 관리하는 것
# - 관련된 기능들을 하나의 디렉터리 구조로 구성한 것
# - 대규모 프로그램에서 코드 관리와 구조화를 위해 사용하는 단위

# 라이브러리
# - 여러개의 모듈들을 묶어 특정 기능을 제공하는 패키지 집합
# - 여러 모듈 + 하위 패키지 구조
# - 특정 목적을 위한 기능 모음
# - 외부라이브러리
# - 내부(표준)라이브러리

# 내부(표준)라이브러리
#

# %%
# 수학 모듈
# 수학 계산 기능을 제공하는 모듈
# 제곱근, 삼각함수, 원주율 등을 포함
import math

# 16의 제곱근 계산
print(math.sqrt(16))
# Out:
# 4.0

# %%
# 난수 모듈 라이브러리
# 게임, 추첨, 테스트 데이터에 사용
import random

print(random.randint(1,100))
# Out:
# 17

# %%
# 날짜/시간 모듈
# 날짜와 시간을 다루는 모듈
import datetime

# 현재 날짜와 시간을 출력
print(datetime.datetime.now())
# Out:
# 2026-02-26 13:03:22.340581

# %%
# 시간 제어 모듈
# 시간 흐름을 제어하는 모듈
# 프로그램을 잠시 멈출 때 사용

import time

# 프로그램을 3초동안 멈춘다
time.sleep(3)

# 3초가 지난 후 출력
print("3초 후 실행")
# Out:
# 3초 후 실행

# %%
# 시스템 모듈
# 파이썬 실행 환경을 다루는 모듈
# 버전 확인, 프로그램 종료 사용
import sys

# 현재 사용중인 파이썬 버전 출력
print(sys.version)
print(sys.path)
# Out:
# 3.14.3 (tags/v3.14.3:323c59a, Feb  3 2026, 16:04:56) [MSC v.1944 64 bit (AMD64)]
# ['c:\\Users\\201\\AppData\\Local\\Programs\\Python\\Python314\\python314.zip', 'c:\\Users\\201\\AppData\\Local\\Programs\\Python\\Python314\\DLLs', 'c:\\Users\\201\\AppData\\Local\\Programs\\Python\\Python314\\Lib', 'c:\\Users\\201\\AppData\\Local\\Programs\\Python\\Python314', '', 'C:\\Users\\201\\AppData\\Roaming\\Python\\Python314\\site-packages', 'c:\\Users\\201\\AppData\\Local\\Programs\\Python\\Python314\\Lib\\site-packages']

# %%
# 운영체제 모듈
# 운영체제(os)와 관련된 기능 제공

import os

print(os.getcwd())
# Out:
# c:\python_study\st3\py_ex2602

# %%
# 데이터 형식 모듈
# JSON 형식으로 데이터를 변환
# - JSON: 데이터를 약속된 모양으로 적는 방식 ("key": "value")
# 웹, API, 파일 저장에 사용
# - API : 프로그램끼리 대화하는 방법(규칙)


import json

data = {"name": "jin", "age": 20}

print(json.dumps(data))
# Out:
# {"name": "jin", "age": 20}

# %%
# 정규표현식 모듈
# 문자열 패턴 검사 모듈
# 형식 확인(아이디, 이메일 등)에 사용

import re

# 문자열이 "hi"로 시작하는지 확인
print(bool(re.match('hi', 'hi python')))
# Out:
# True

# %%
# csv 파일 모듈
# csv(엑셀) 파일을 읽고 쓰는 모듈
# 데이터 저장/분석 기초에 사용

import csv

# csv 파일에 한 줄 데이터 저장
with open('test.csv', 'w', newline='') as f:
    csv.writer(f).writerow(['name', 'score'])

# %%
# 자료구조 모듈
# 자료구조를 편하게 쓰도록 도와줌
# 카운트, 큐, 딕셔너리 확장 기능 제공

from collections import Counter

# 문자열에서 각 글자의 개수를 셈
print(Counter("apple"))
# Out:
# Counter({'p': 2, 'a': 1, 'l': 1, 'e': 1})
