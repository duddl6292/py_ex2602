# %%
import ex1

print(ex1.fun1())

print(ex1.fun2())

print(ex1.fun3())

print(ex1.fun4())
# Out:
# 모듈에 있는 첫 번째 함수
# 10
# 안녕
# 모듈에 있는 마지막 함수

# %%
from ex1 import fun1, fun2

print(fun1())

print(fun2())
# Out:
# 모듈에 있는 첫 번째 함수
# 10
