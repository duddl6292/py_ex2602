# %%
import ex1

print(ex1.fun1())

print(ex1.fun2())

print(ex1.fun3())

print(ex1.fun4())
# Out:
# 모듈에 있는 첫 번째 함수
# 10
# 안녕
# 모듈에 있는 마지막 함수

# %%
from ex1 import fun1, fun2, fun3

print(fun1())

print(fun2())

print(fun3())
# Out:
# 모듈에 있는 첫 번째 함수
# 10
# 안녕

# %%
import os, sys

sys.path.append(os.getcwd())

# %%
import sys

print(sys.path)
# Out:
# ['c:\\Users\\201\\AppData\\Local\\Programs\\Python\\Python314\\python314.zip', 'c:\\Users\\201\\AppData\\Local\\Programs\\Python\\Python314\\DLLs', 'c:\\Users\\201\\AppData\\Local\\Programs\\Python\\Python314\\Lib', 'c:\\Users\\201\\AppData\\Local\\Programs\\Python\\Python314', '', 'C:\\Users\\201\\AppData\\Roaming\\Python\\Python314\\site-packages', 'c:\\Users\\201\\AppData\\Local\\Programs\\Python\\Python314\\Lib\\site-packages', 'c:\\python_study\\st3\\py_ex2602']
