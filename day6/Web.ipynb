# %%
# 웹 스크래핑 
# - 특정 페이지에서 원하는 정보만 뽑아 내는 것

# 웹 크롤링 
# - 여러 웹 페이지를 자동으로 돌아다니며 수집하는 것

# %%
# 웹페이지

# == HTML 문서 ==
# tag로 만들어진다
# - 마크업이라는 걸 할 수 있다. (뼈대)
# - 배우

# == CSS == 
# - 마크업이 된 엘리먼트를 찾아서 꾸며줄 수 있다.
# - 스타일리스트

# 태그 : 여는 태그 + 닫는 태그
# 엘리먼트 : 태그 세트

# 제목(<h>, h뒤 숫자가 작을 수록 큰 제목)
# <h1> 뉴스 제목 </h1>
# <h2>
# ...
# <h6>

# 본문
# <p> ... </p>
