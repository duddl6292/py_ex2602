# %%
# 우리가 url를 검색하면 네이버에서 html로 답을 줌 
# 근데 html대신 python으로 받는걸 웹스크래핑이라고 함

# %%
# requests 모듈 ->  웹 페이지를 요청하고 응답 데이터를 받을 수 있음
import requests as req

response = req.get("https://www.naver.com")

print(response)
# Out:
# <Response [200]>

# %%
import requests as req
from bs4 import BeautifulSoup # BeautifulSoup => html 해석기(파이썬이 html을 알도록)

#요청시 오류 났을 때 아래 문구를 입력해주세요.

request_headers = {'User-Agent': ('Mozilla/5.0 (Windows NT 10.0;Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36'), }

response = req.get("https://www.naver.com", request_headers)

# print(response)

html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# print(html_doc)

soup = BeautifulSoup(html_doc, 'html.parser')
# soup을 이용해서 html_doc 문자열 파싱, 그 내용을 soup 변수에 대입

a_list = soup.select('a')
print("== a태그 리스트 ==")
print(a_list)

print("== a태그 리스트 중 첫 번째 ==")
print(a_list[0])

print("== a태그 리스트 중 첫 번째의 text만 ==")
print(a_list[0].text)

print("== a태그 리스트들의 text만 모두 출력 ==")
for t in a_list:
    print(t.text)
    
print("== a태그 리스트들 중 첫 번째의 link ==")
print(a_list[0]['href'])    
    
print("== a태그 리스트들 중 link만 모두 출력 ==")    
for link in a_list:
    print(link['href']) # 속성을 선택할 땐 대괄호
# Out:
# == a태그 리스트 ==
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]
# == a태그 리스트 중 첫 번째 ==
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# == a태그 리스트 중 첫 번째의 text만 ==
# Elsie
# == a태그 리스트들의 text만 모두 출력 ==
# Elsie
# Lacie
# Tillie
# == a태그 리스트들 중 첫 번째의 link ==
# http://example.com/elsie
# == a태그 리스트들 중 link만 모두 출력 ==
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
'''
html
<div>
<a class="sister" href="http://example.com/elsie" id="link1">
Elsie
</a>
</div>

css
1. 태그 선택
    - a{color : red;}

2. 후손 선택 (div 밑에 있는 모든 a)
    - div a
    
3. 자식 선택 (div 바로 밑에 있는 a)
    - div > a 

4. 클래스 선택
    - .sister{ color : red; }
    
5. id 선택
    - #link1 { color : red; }
    

html 선택 방법 (css 선택자)
1. 태그 선택 : <a href=""></a>
2. 후손 선택
3. 자식 선택
4. 클래스 선택
5. id 선택
'''

# %%
import requests as req
from bs4 import BeautifulSoup

response = req.get("https://news.naver.com/")
# print(response)
# print(response.text)

# html 문자열 파싱
soup = BeautifulSoup(response.text, 'html.parser')

# content = soup.select('.cnf_news_title')
# print(content[0].text)

# # print("\n\n\n\n== class로 선택, 반복문으로 텍스트 출력 ==")
# # for c in content:
# #     print(c.text)
    
# content2 = soup.select('.cn_title_area > h4')

# print("\n\n\n\n== 자식 선택자로 선택, 반복문으로 텍스트 출력 ==")
# for c in content2:
#     print(c.text)

imgs = soup.select('.cnf_news_thumb > img')

print("== 자식 선택자로 선택, 반복문으로 이미지 주소 출력 ==")
for img in imgs:
    print(img['data-src']) # print(img['src'])
# Out:
# == 자식 선택자로 선택, 반복문으로 이미지 주소 출력 ==
# https://mimgnews.pstatic.net/image/origin/088/2026/02/27/998807.jpg?type=nf168_108&ut=20260227142616
# https://mimgnews.pstatic.net/image/origin/056/2026/02/27/12132522.jpg?type=nf168_108&ut=20260227142317
# https://mimgnews.pstatic.net/image/origin/055/2026/02/27/1336287.jpg?type=nf168_108&ut=20260227145213
# https://mimgnews.pstatic.net/image/origin/661/2026/02/27/72012.jpg?type=nf168_108&ut=20260227133618
# https://mimgnews.pstatic.net/image/origin/656/2026/02/27/168682.jpg?type=nf168_108&ut=20260227135714
# https://mimgnews.pstatic.net/image/origin/023/2026/02/27/3961517.jpg?type=nf168_108&ut=20260227144614
# https://mimgnews.pstatic.net/image/origin/654/2026/02/27/168533.jpg?type=nf168_108&ut=20260227141710
# https://mimgnews.pstatic.net/image/origin/047/2026/02/27/2506236.jpg?type=nf168_108&ut=20260227115613
# https://mimgnews.pstatic.net/image/origin/021/2026/02/27/2773861.jpg?type=nf168_108&ut=20260227141814
# ...
